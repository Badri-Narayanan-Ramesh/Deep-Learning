# %% [markdown]
# Facial Expression Recognition using Deep CNN

# %% [markdown]
# - Task: Facial Expression Recognition (anger, fear, surprise, etc.)
# - Model: Deep CNN based on DeXpression
# - Dataset: Extended Cohn–Kanade (CK+)
# - Eval: 5-fold cross-validation
# - Results: 99.47% train, 98.98% test accuracy
